# %%
import pandas as pd
import numpy as np

running_goals = pd.read_csv("experiment_data/running_goals.csv", sep=';', index_col='example')
walking_goals = pd.read_csv("experiment_data/walking_goals.csv", sep=';', index_col='example')
user_examples = pd.read_csv("experiment_data/user_examples.csv", sep=';', index_col='id')

# %%
running_goals
# Out:
#                                               introduction  \
# example
# 2        I'm 21 years old. I've practised volleyball fo...
# 4        Hi, my name is Mary. I tend to define myself a...
# 8        I love doing physical activity, especially run...
# 15       My name is Linda and I love outdoor activities...
# 19       I am into gymnastics a lot. I used to attend P...
# 23       I'm just getting back into a little bit of lig...
# 25       Hi, I'm Elizabeth. I am an active working mum....
# 26       Hello, my name is Lisa, in the mornings and in...
# 27       I really like to run and be active. I like goi...
# 28       Hey! My name is Barbara. I come from Italy. I ...
# 29       Hi, my name is Jessica and I like to live an a...
# 30       Hi, I am very interested in exchanging our exp...
# 33       Hi. I take jogging and low-impact aerobic exer...
# 36       I'm doing a lot of workouts. I run regularly, ...
# 38       I am 23 years old, I do not like exercising at...
# 50       Hello, I'm Daniel. I always took care of my bo...
# 53       Hi, my name is Brian, I'm 42 years old, I like...
# 54       I'm a person that likes to do activities. I li...
# 55       I am 39 years old and try to be in good physic...
# 56       Hello, I'm Edward. I'm 49 years old. I'm a per...
# 62       Hello, my name is Joseph and I'm a 29-year-old...
# 64       Hi, nice to meet you. I started running a year...
# 65       I really like cycling on the weekends. I don't...
# 67       Hello, I am an energetic individual who enjoys...
#
#                                                       goal  \
# example
# 2                         I was able to run 4 km in a row.
# 4               I started running for 2 km now I run 4 km.
# 8        I ran a race for the cause Neurofibromatosis t...
# 15       In the past year, I was able to run for 10 km,...
# 19         I won the bronze medal which means I ran 25 km.
# 23       I ran further each time than the time before t...
# 25       I barely ran prior to the last year but now, I...
# 26       I set the goal of going out for a run every da...
# 27           My goal was to run 10 km in under 40 minutes.
# 28                          I followed my jogging program.
# 29            My goal was to be able to run 5 miles a day.
# 30                         I ran every day for 30 minutes.
# 33                     I've jogged longer than previously.
# 36             I ran 10 km in under 1 hour and 10 minutes.
# 38       A few months ago I started running. I was real...
# 50                     I went from running 1 km to 3-5 km.
# 53       Last year I managed to achieve my goal of runn...
# 54       I ran a half marathon, which has been one of t...
# 55               With walking and running, I lost 7 kilos.
# 56       I increased the number of daily kilometers I w...
# 62       I pushed myself to be able to run for a longer...
# 64       I ran all around the park near my home in less...
# 65                               I ran 100m in 12 seconds.
# 67        I walked at least 5 km a week for a whole month.
#
#                                                        how
# example
# 2        I achieved this by walking almost every day an...
# 4        I achieved this by forcing myself to go out ru...
# 8        I achieved this because I promised my son, who...
# 15       I achieved this because I kept practicing non-...
# 19       I achieved this by taking part in a local race...
# 23       I achieved this with determination to really k...
# 25       I strayed slowly and worked my way up from the...
# 26       I achieved this by motivating myself that this...
# 27       I achieved this by training every day for a year.
# 28       I achieved this because I have an app that hel...
# 29       I achieved this because I gradually increased ...
# 30       I achieved this by running every day for 30 mi...
# 33       I've achieved this goal by becoming more deter...
# 36       I achieved this by gradually increasing the di...
# 38       At the start, I could only run 1-2 km. I start...
# 50       I achieved this with consistency and fewer thi...
# 53       I reached my goal after feeling ready to do it...
# 72       Walking goal  I have a new dog and we walk together at least...
# 73       Walking goal  I am a very active person who likes to go out ...
#
#                                                       goal  \
# example
# 1        For one month earlier this year, I walked 5 mi...
# 3                 I walked every day at least 6.000 steps.
# 5         I walked 10.000 steps each day for a whole week.
# 6        I walked more than 10.000 steps per day for 12...
# 7                   I walked and ran more during lockdown.
# 9                 I reached over 10.000 steps in 24 hours.
# 10        I am now able to walk half a mile 3 days a week.
# 11       I have designated a lot more time for walking ...
# 12       I have walked to all four corners of my town a...
# 13             I walked between 30 min and 1 hour per day.
# 14                        I walked 10 km in under 4 hours.
# 16                             I walked 50 km over 2 days.
# 17       I’ve actively made it a priority to walk at le...
# 18       I have walked 10.000 steps a day for 14 days s...
# 20       I walked for at least one hour, three times a ...
# 21       My goal was to walk at least 5 days a week for...
# 22       I have surpassed my goal, I am now able to wal...
# 24       I think the best sport for me is walking. I wa...
# 31       I increased the time that I am walking by walk...
# 32       I have walked more than 10.000 steps in half a...
# 34       My goal was to walk at least one hour each day...
# 35       I walked 5 km per day every day. It was tough ...
# 37                    I've walked a half marathon on feet.
# 39                         I walked 2 km 2 times per week.
# 40       The daily goal that I have achieved was to wal...
# 41       I set a goal to walk every day regardless of w...
# 42       I managed to climb a mountain in Asturias that...
# 43        I increased my dog walks to 3 miles twice a day.
# 44       I walked every day, slowly increasing my dista...
# 45                  I did my 10 km walking goal last week.
# 46             I walked a 3-mile circuit on a daily basis.
# 47                     I walked for one hour twice a week.
# 48             I walked around the local field once a day.
# 49        I walked at least 5 km a week for a whole month.
# 51       I increased the number of daily kilometers I w...
# 52          I walked 15 km in a mountain without stopping.
# 57        I walked10.000 steps while not paying attention.
# 58       I climbed a medium difficulty mountain top, 2....
# 59                         I reached 20.000 steps per day.
# 60       I walked 17.2 miles only two days ago, which w...
# 61                 I started walking after a heart attack.
# 63          I started walking with my girlfriend at night.
# 66                    I have walked for an hour every day.
# 68       My pride of this year as of walking is when I ...
# 69       I achieved walking to the nearest town and wal...
# 70       Last year I hardly walked or exercised due to ...
# 71       I managed to walk 10 miles in one go without s...
# 72                   I walked around the county of Galway.
# 73       I did medium and long-distance routes through ...
#
#                                                        how
# example
# 1        I achieved this because my sister really motiv...
# 3        I achieved this by just going for walks alone,...
# 5           I achieved this by walking with a new student.
# 6        I achieved this because I walked the dog more ...
# 7        I achieved this by walking more through lockdo...
# 9        I achieved this by walking daily along beaches...
# 10       I achieved this with my swimming and by losing...
# 11       I achieved this by purposefully making time to...
# 12       I achieved this with passion, determination, a...
# 13       I achieved this by realizing that the more you...
# 14       I achieved this with good shoes and lots of wa...
# 16         I achieved this with perseverance and teamwork.
# 17       I achieved this because it is set on the famil...
# 18       I achieved this by monitoring my steps using m...
# 20       I achieved this with sheer bloody-mindedness, ...
# 21       I achieved this by just trying to walk every d...
# 22       I achieved this by buying myself an Apple Watc...
# 24       I achieved this by walking every day for 2 hou...
# 31       I achieved this by building up my walks by doi...
# 32       I achieved this by walking everywhere I needed...
# 34       I achieved this by using a fit watch, by alloc...
# 35       I achieved this with consistency and thanks to...
# 37       I achieved this with regularity and the will t...
# 39       I achieved this by waking up much earlier than...
# 40         I achieved this by walking to numerous places.
# 41       I achieved this by setting all my feelings asi...
# 42           I achieved this with perseverance and effort.
# 43       I achieved this by having a set routine when I...
# 44       I achieved this because my wife and I made a p...
# 45       I achieved this by just pushing myself to the ...
# 46       I achieved this because every day after breakf...
# 47       I achieved this by overcoming my social and ge...
# 48       I achieved this by forcing myself to do it as ...
# 49       I achieved this by walking to the grocery stor...
# 51       I achieved this by increasing the number of ki...
# 52       I achieved this by taking a lot of smaller wal...
# 57       I achieved this by taking a walk around town w...
# 58       I achieved this by preparing well the previous...
# 59       I achieved this by constantly pushing myself t...
# 60       I always try to get more than halfway in half ...
# 61       I achieved this by walking every day after din...
# 63       I achieved this because we just jumped for it ...
# 66       I achieved this by writing a schedule every da...
# 68       I achieved this by wearing suitable shoes, hav...
# 69       I started with small walks which became longer...
# 70       I achieved this by making sure I go out every ...
# 71       I achieved this with lots of practice and prep...
# 72       We had 5 months in which to walked 573 km, so ...
# 73       I achieved this by planning the route by looki...

# %%
user_examples
# Out:
#        run1  run2  walk1  walk2
# id
# beyza     2     4      1      3
# nele      8    15      5      6
# user1    19    23      7      9
# user2    25    26     10     11
# user3    27    28     70     71
# user4    65    67     72     73

# %%
user_examples.loc['beyza']['run1']
# Out:
# 2

# %%
import pandas as pd
goals = pd.read_csv("experiment_data/goals.csv", sep=';', index_col='example')
goals
# Out:
#                                               introduction  \
# example
# 1        I’m looking to improve my health and fitness a...
# 3        I'm Patricia and I really like playing tennis ...
# 5        I am an almost 50-year-old woman and work with...
# 6        I'm looking to lose the weight I put on during...
# 7        I'm 51, not really physically fit but trying. ...
# ...                                                    ...
# 56       Hello, I'm Edward. I'm 49 years old. I'm a per...
# 62       Hello, my name is Joseph and I'm a 29-year-old...
# 64       Hi, nice to meet you. I started running a year...
# 65       I really like cycling on the weekends. I don't...
# 67       Hello, I am an energetic individual who enjoys...
#
#                                                       goal  \
# example
# 1        For one month earlier this year, I walked 5 mi...
# 3                 I walked every day at least 6.000 steps.
# 5         I walked 10.000 steps each day for a whole week.
# 6        I walked more than 10.000 steps per day for 12...
# 7                   I walked and ran more during lockdown.
# ...                                                    ...
# 56       I increased the number of daily kilometers I w...
# 62       I pushed myself to be able to run for a longer...
# 64       I ran all around the park near my home in less...
# 65                               I ran 100m in 12 seconds.
# 67        I walked at least 5 km a week for a whole month.
#
#                                                        how
# example
# 1        I achieved this because my sister really motiv...
# 3        I achieved this by just going for walks alone,...
# 5           I achieved this by walking with a new student.
# 6        I achieved this because I walked the dog more ...
# 7        I achieved this by walking more through lockdo...
# ...                                                    ...
# 56       I achieved this because I started with shorter...
# 62       I achieved this by keeping up with my running ...
# 64       I achieved my goal by trying to do a little be...
# 65             I achieved this by sprinting 3 times a week
# 67       I achieved this because I was motivated by the...
#
# [73 rows x 3 columns]

# %%
import pandas as pd
user_examples = pd.read_csv("experiment_data/user_examples.csv", sep=';', index_col='id')
user_examples
goals = pd.read_csv("experiment_data/goals.csv", sep=';', index_col='example')

# %%
index = user_examples.loc['beyza']['example1']
intro1 = "🧍* " + goals.loc[index]['introduction']+"*"
goalhow1 = "**"+"🎯 " + goals.loc[index]['goal'] + " " + goals.loc[index]['how']+"**"
